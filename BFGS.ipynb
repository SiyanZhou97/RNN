# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize, least_squares
import os
import inspect
import math
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
os.sys.path.insert(0,parentdir)
from src.Tools import generate_inputWN,moving_bump

# %% [markdown]
# # 1 Fit output of RNN

# %%
n_step=41
dim_rec=300

# %% [markdown]
# Define an interesting 2-d sequential output pattern:

# %%
target=np.zeros((41,2))
for i in range(8):
    target[i,0]=1*np.cos(np.pi-np.pi/5*i)+1
    target[i,1]=1*np.sin(np.pi-np.pi/5*i)
target[8,0]=0.8
target[8,1]=-1.3
target[9,0]=0.4
target[9,1]=-1.6
for i in range(10,15):
    target[i,0]=target[0,0]+0.5*(i-10)
    target[i,1]=-2
for i in range(15,25):
    target[i,0]=1*np.cos(-np.pi/2-np.pi/5*(i-15))+3.7
    target[i,1]=1.5*np.sin(-np.pi/2-np.pi/5*(i-15))-0.5
for i in range(25,34):
    target[i,0]=2/1.8*np.cos(np.pi*6/5+np.pi/5*(i-25))+6.4
    target[i,1]=1*np.sin(np.pi*6/5+np.pi/5*(i-25))-1
target[34:36,0]=target[33,0]
target[34:36,1]=np.linspace(target[33,1],1,4)[1:3]
for i in range(36,41):
    target[i,0]=target[35,0]+0.5*(i-36)
    target[i,1]=1
target=target[:n_step,:].T

# %%
fig,ax=plt.subplots(figsize=(8,4))
plt.plot(target[0,:],target[1,:],marker='o',ms=10,c='k',lw=2)
plt.xlim(-1,8.5)
plt.ylim(-2.5,1.5)
plt.xlabel('x',size=15)
plt.ylabel('y',size=15)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Use filtered white noise as the inputs to the RNN - it is a rich source of dynamics

# %%
inputs=generate_inputWN(n_step=n_step,dim_rec=dim_rec,tauWN=1,ampWN=30,dt=0.001).astype('float32')

# %%
x0=np.zeros(dim_rec)
J= 0.9 * np.random.randn(dim_rec, dim_rec) / math.sqrt(dim_rec)
Wfb = 0.9 * np.random.randn(dim_rec, target.shape[0]) / math.sqrt(target.shape[0])
def rnnLN(W):
    pred=np.zeros(target.shape)
    for i in range(n_step):
        if i == 0:
            x = x0
        else:
            x = np.dot(J, np.tanh(x)) + np.dot(Wfb,output)+ inputs[:,i] 
        output=np.dot(W, np.tanh(x))
        pred[:,i]=output
    return pred
def loss(W):
    W=W.reshape(-1,dim_rec)
    pred=rnnLN(W)
    return np.mean(np.square(target-pred))

# %%
history=[]
n=0
def callback(x):
    W=x.reshape(-1,dim_rec)
    pred=rnnLN(W)
    history.append(np.mean(np.square(target-pred)))
    print(f'iteration{len(history)}:{history[-1]}')
    if len(history)>=2 and history[-1]-history[-2]>1e-10:
        return False

# %%
W0 =np.zeros((target.shape[0],dim_rec))

# %%
res = minimize(fun=loss, x0=W0.flatten(), method='BFGS',  jac="2-point", hess='2-point',tol=1e-16,
                        callback=callback,options={'maxiter':1000,'disp':True})
# Out:
# /home/sz154/jupyterenv/lib/python3.7/site-packages/scipy/optimize/_minimize.py:528: RuntimeWarning: Method BFGS does not use Hessian information (hess).
#   RuntimeWarning)
# iteration1:6.400147692196263
# iteration2:3.5237423852455403
# iteration3:2.79768785599616
# iteration4:2.756973380929531
# iteration5:2.421127765878052
# iteration6:1.0358876791442095
# iteration7:1.0350333626373236
# iteration8:1.0030361158426468
# iteration9:0.9467316805546577
# iteration320:0.0002197405048239994
# iteration321:0.00021772781485776806
# iteration322:0.0002149800364888693
# iteration323:0.00021355030567029839
# iteration324:0.00021136039965770635
# iteration325:0.00020738364023228847
# iteration326:0.00020088054544039355
# iteration327:0.00019584963912088653
# iteration328:0.0001952813360084192
# iteration329:0.0001943351783256807
# iteration330:0.0001927371398597508
# iteration331:0.00019114012503452076
# iteration332:0.00019010016073237417
# iteration333:0.00018834544984896944
# iteration334:0.00018690556302802434
# iteration335:0.00018442843039870877
# iteration336:0.00018012575832779173
# iteration337:0.00017297822862644502
# iteration338:0.00016485505240035643
# iteration339:0.00016426125167163779
# iteration340:0.0001630952898866766
# iteration341:0.00016094456629307067
# iteration342:0.00015826309926214545
# iteration343:0.0001570737054527674
# iteration344:0.0001552772172901582
# iteration345:0.00015266816364678046
# iteration346:0.00015176378039185944
# iteration347:0.00015056331805928772
# iteration348:0.0001490310602668355
# iteration349:0.00014668754329277673
# iteration350:0.00014267127337008975
# iteration351:0.00014034817573789499
# iteration352:0.00013835716039579637
# iteration353:0.0001369681099585331
# iteration354:0.00013554598868931606
# iteration355:0.00013425596241073968
# iteration356:0.0001327287084583233
# iteration357:0.00013038292656979118
# iteration358:0.00012794079127906912
# iteration359:0.0001253679921056521
# iteration360:0.00012188587926544121
# iteration361:0.00011831361582104371
# iteration362:0.0001169718733254298
# iteration363:0.00011513415102384099
# iteration364:0.00011191406465694603
# iteration365:0.00010963295237964399
# iteration366:0.00010908815764310496
# iteration367:0.00010788048812221419
# iteration368:0.00010535881386798854
# iteration369:0.00010152857064805829
# iteration370:9.928639463056447e-05
# iteration371:9.464109026838934e-05
# iteration372:8.786857354718778e-05
# iteration373:8.675302417553739e-05
# iteration374:8.562815467486241e-05
# iteration375:8.486619977958202e-05
# iteration376:8.352847286952438e-05
# iteration377:8.24856362937756e-05
# iteration378:8.119318352237595e-05
# iteration379:7.889096820373494e-05
# iteration380:7.65765956438815e-05
# iteration381:7.461744255395325e-05
# iteration382:7.387329544020488e-05
# iteration383:7.317959461736786e-05
# iteration384:7.277763176773063e-05
# iteration385:7.240553710711818e-05
# iteration386:7.21302300381838e-05
# iteration387:7.194240333148581e-05
# iteration388:7.154736134894176e-05
# iteration389:7.141852276477008e-05
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.000071
#          Iterations: 389
#          Function evaluations: 301113
#          Gradient evaluations: 501

# %%
W=res['x'].reshape(-1,dim_rec)

# %%
pred=rnnLN(W)

# %%
fig,ax=plt.subplots(figsize=(8,4),dpi=70)
plt.plot(target[0,:],target[1,:],marker='o',ms=10,c='k',label='target')
plt.plot(pred[0,:],pred[1,:],marker='o',ms=10,c='r',label='RNN output')
plt.xlim(-1,8.5)
plt.ylim(-2.5,1.5)
plt.xlabel('x',size=15)
plt.ylabel('y',size=15)
plt.legend(loc=6)

# %%
RLS_lc=np.load(f'/home/sz154/mse_lc.npy',allow_pickle=True)

# %%
fig,ax=plt.subplots(figsize=(5,4),dpi=100)
plt.plot(RLS_lc,label='RLS')
plt.plot(history,label='BFGS')

plt.yscale('log')
plt.xlabel('Iterations',size=15)
plt.ylabel('Mean sqaure error',size=15)
plt.title('Learning curve',size=15)
plt.legend()
